# %% [markdown]
# <h1>Sumário<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Resumo" data-toc-modified-id="Resumo-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Resumo</a></span></li><li><span><a href="#Introdução" data-toc-modified-id="Introdução-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Introdução</a></span></li><li><span><a href="#Imports-and-Functions" data-toc-modified-id="Imports-and-Functions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Imports and Functions</a></span><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Functions</a></span><ul class="toc-item"><li><span><a href="#Gráficos" data-toc-modified-id="Gráficos-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Gráficos</a></span></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Outliers</a></span></li><li><span><a href="#Frequência-das-Classes-Categóricas" data-toc-modified-id="Frequência-das-Classes-Categóricas-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Frequência das Classes Categóricas</a></span></li><li><span><a href="#Ajuste-de-Dados" data-toc-modified-id="Ajuste-de-Dados-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Ajuste de Dados</a></span></li><li><span><a href="#Automatic-Feature-Selection-in-Python" data-toc-modified-id="Automatic-Feature-Selection-in-Python-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Automatic Feature Selection in Python</a></span></li><li><span><a href="#Funções-para-Treinamento-e-Avaliação-de-Modelos-de-ML" data-toc-modified-id="Funções-para-Treinamento-e-Avaliação-de-Modelos-de-ML-3.2.6"><span class="toc-item-num">3.2.6&nbsp;&nbsp;</span>Funções para Treinamento e Avaliação de Modelos de ML</a></span><ul class="toc-item"><li><span><a href="#Hyperparameter-Tuning" data-toc-modified-id="Hyperparameter-Tuning-3.2.6.1"><span class="toc-item-num">3.2.6.1&nbsp;&nbsp;</span>Hyperparameter Tuning</a></span></li><li><span><a href="#GridSerachCV" data-toc-modified-id="GridSerachCV-3.2.6.2"><span class="toc-item-num">3.2.6.2&nbsp;&nbsp;</span>GridSerachCV</a></span></li><li><span><a href="#Random-Search" data-toc-modified-id="Random-Search-3.2.6.3"><span class="toc-item-num">3.2.6.3&nbsp;&nbsp;</span>Random Search</a></span></li><li><span><a href="#Treino-X-Teste" data-toc-modified-id="Treino-X-Teste-3.2.6.4"><span class="toc-item-num">3.2.6.4&nbsp;&nbsp;</span>Treino X Teste</a></span></li><li><span><a href="#Métricas" data-toc-modified-id="Métricas-3.2.6.5"><span class="toc-item-num">3.2.6.5&nbsp;&nbsp;</span>Métricas</a></span></li></ul></li><li><span><a href="#Funções-de-Interpretabilidade" data-toc-modified-id="Funções-de-Interpretabilidade-3.2.7"><span class="toc-item-num">3.2.7&nbsp;&nbsp;</span>Funções de Interpretabilidade</a></span></li></ul></li></ul></li><li><span><a href="#Análise-Exploratória" data-toc-modified-id="Análise-Exploratória-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Análise Exploratória</a></span><ul class="toc-item"><li><span><a href="#Importando-DataFrame" data-toc-modified-id="Importando-DataFrame-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Importando DataFrame</a></span></li><li><span><a href="#Alterando-Nome-das-Colunas-e-Separando-por-tipo" data-toc-modified-id="Alterando-Nome-das-Colunas-e-Separando-por-tipo-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Alterando Nome das Colunas e Separando por tipo</a></span></li><li><span><a href="#Informações-do-DataFrame" data-toc-modified-id="Informações-do-DataFrame-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Informações do DataFrame</a></span></li><li><span><a href="#Distribuição-Colunas-Categóricas" data-toc-modified-id="Distribuição-Colunas-Categóricas-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Distribuição Colunas Categóricas</a></span></li><li><span><a href="#Distribuição-Colunas-Quantitativas" data-toc-modified-id="Distribuição-Colunas-Quantitativas-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Distribuição Colunas Quantitativas</a></span><ul class="toc-item"><li><span><a href="#Outliers" data-toc-modified-id="Outliers-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Outliers</a></span></li></ul></li><li><span><a href="#Outras-Relações" data-toc-modified-id="Outras-Relações-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Outras Relações</a></span></li></ul></li><li><span><a href="#Tratamento-de-Dados" data-toc-modified-id="Tratamento-de-Dados-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Tratamento de Dados</a></span><ul class="toc-item"><li><span><a href="#Eliminando-outliers" data-toc-modified-id="Eliminando-outliers-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Eliminando outliers</a></span></li><li><span><a href="#Eliminando-Classes" data-toc-modified-id="Eliminando-Classes-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Eliminando Classes</a></span><ul class="toc-item"><li><span><a href="#Teste-de-Estresse" data-toc-modified-id="Teste-de-Estresse-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Teste de Estresse</a></span></li><li><span><a href="#Eletrocardiograma" data-toc-modified-id="Eletrocardiograma-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Eletrocardiograma</a></span></li><li><span><a href="#Número-de-Vasos" data-toc-modified-id="Número-de-Vasos-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Número de Vasos</a></span></li><li><span><a href="#Tipo-de-Dor-no-Peito" data-toc-modified-id="Tipo-de-Dor-no-Peito-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Tipo de Dor no Peito</a></span></li><li><span><a href="#Teste-de-Estresse" data-toc-modified-id="Teste-de-Estresse-5.2.5"><span class="toc-item-num">5.2.5&nbsp;&nbsp;</span>Teste de Estresse</a></span></li><li><span><a href="#Inclinação" data-toc-modified-id="Inclinação-5.2.6"><span class="toc-item-num">5.2.6&nbsp;&nbsp;</span>Inclinação</a></span></li><li><span><a href="#Plot" data-toc-modified-id="Plot-5.2.7"><span class="toc-item-num">5.2.7&nbsp;&nbsp;</span>Plot</a></span></li></ul></li><li><span><a href="#Balanceamento-de-Classes" data-toc-modified-id="Balanceamento-de-Classes-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Balanceamento de Classes</a></span><ul class="toc-item"><li><span><a href="#Balanceamento-da-classe-Glicemia-em-jejum" data-toc-modified-id="Balanceamento-da-classe-Glicemia-em-jejum-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Balanceamento da classe Glicemia em jejum</a></span></li><li><span><a href="#Balanceamento-da-classe-Número-de-Vasos" data-toc-modified-id="Balanceamento-da-classe-Número-de-Vasos-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Balanceamento da classe Número de Vasos</a></span></li><li><span><a href="#Balanceamento-da-classe-Risco" data-toc-modified-id="Balanceamento-da-classe-Risco-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Balanceamento da classe Risco</a></span></li></ul></li><li><span><a href="#Padronização-Dos-Dados" data-toc-modified-id="Padronização-Dos-Dados-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Padronização Dos Dados</a></span></li><li><span><a href="#Seleção-de-Features" data-toc-modified-id="Seleção-de-Features-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Seleção de Features</a></span></li></ul></li><li><span><a href="#Treinamentos" data-toc-modified-id="Treinamentos-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Treinamentos</a></span><ul class="toc-item"><li><span><a href="#Treino-x-Teste" data-toc-modified-id="Treino-x-Teste-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Treino x Teste</a></span></li><li><span><a href="#Instâncias-dos-Modelos" data-toc-modified-id="Instâncias-dos-Modelos-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Instâncias dos Modelos</a></span></li><li><span><a href="#KNN" data-toc-modified-id="KNN-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>KNN</a></span><ul class="toc-item"><li><span><a href="#Interpretabilidade" data-toc-modified-id="Interpretabilidade-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Interpretabilidade</a></span></li></ul></li><li><span><a href="#SVM" data-toc-modified-id="SVM-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>SVM</a></span><ul class="toc-item"><li><span><a href="#Interpretabilidade" data-toc-modified-id="Interpretabilidade-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Interpretabilidade</a></span></li></ul></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Decision Tree</a></span><ul class="toc-item"><li><span><a href="#Interpretabilidade" data-toc-modified-id="Interpretabilidade-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Interpretabilidade</a></span></li></ul></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Random Forest</a></span><ul class="toc-item"><li><span><a href="#Interpretabilidade" data-toc-modified-id="Interpretabilidade-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>Interpretabilidade</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Resumo
# O trabalho apresentado demonstra a análise exploratória e aplicação de modelos de machine learning para classificação da base de dados escolhida, objetivando o melhor desempenho ao fim da classificação.

# %% [markdown]
# # Introdução
# O conjunto de dados utilizado foi retirado do site kaggle.com e contém métricas de 303 pacientes que estão categorizados em dois grupos de risco de ataque cardíaco, alto e baixo.<br>
# Conteúdo da base de dados.<br>
#
# - **Age**: Idade do paciente.
# - **Sex**: Sexo do paciente.
# - **cp**: Tipo de dor no peito.
#  - Valor 0: Isquemia comum.
#  - Valor 1: Isquemia incomum.
#  - Valor 2: Dor não isquêmica.
#  - Valor 3: Assintomático.
# - **trtbps**: Pressão arterial sistólica de repouso (in mm Hg).
# - **chol**: Colestoral em mg/dl obtido através do sensor de IMC.
# - **fbs**: Açúcar no sangue em jejum > 120 mg/dl.
#  - Valor 1: Verdadeiro.
#  - Valor 0: Falso.
# - **rest_ecg**: Resultados eletrocardiográficos em repouso.
#  - Valor 0: Normal.
#  - Valor 1: Com anormalidade da onda ST-T (inversões da onda T e/ou elevação ou queda de ST > 0,05 mV).
#  - Valor 2: Mostrando provável ou definitiva hipertrofia ventricular esquerda pelos critérios de Estes.
# - **thalachh**: Frequência cardíaca máxima atingida.
# - **exng**: Isquemia induzida por exercício.
#  - 	Valor 1: = Sim.
#  -	Valor 0: = Não.
# - **oldpeak**: Pico anterior.
# - **slp**: Queda
# - **caa**: Número de vasos principais (0-3)
# - **thall**: Resultado em teste de esforço (0-3)
# - **target**: Resultado.
#  - Valor 0: Menor chance de ataque cardíaco.
#  - Valor 1: Maior chance de ataque cardíaco.

# %% [markdown]
# # Imports and Functions

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
#from sklearn.model_selection import RandomizedSearchCV

#Métricas de Classificação
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import f1_score, recall_score, precision_score
from sklearn.metrics import classification_report

#Classes ML
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

#balanceamento
from imblearn.over_sampling import SMOTE

#Feactures Selection
#Tenta importar biblioteca, senão instala e faz e importa
x=False
while (x==False):
    try:
        from featurewiz import featurewiz
        np.random.seed(1234)
        print("Pacote importado")
        x=True
    except:
        print("Instalando Pacote!")
        # !pip install featurewiz

import time

#interpretabilidade
import shap
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Pacote importado

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Gráficos

# %%
#Recebe Data Frame, Lista de Colunas, 
#lista com corpo do plot desejado. ex:[3,2] exibirá 6 plots com 3linhas 2 colunas. LxC>= qtd lista de Colunas
def countPlot(data,colunms,matriz=[]):
    plt.subplots(figsize=(10, 15))
    for count,column_name in enumerate(colunms,start=1):
        plt.subplot(matriz[0], matriz[1], count)
        sns.countplot(x=column_name,data = data,order = np.sort(data[column_name].unique()))
        plt.title(dicionario[column_name], fontsize=14, fontweight='bold',fontfamily='serif')  
        plt.xlabel("")
        plt.ylabel("")
    plt.show()

def histplot(data,colunms,listaCor,matriz=[]):
    plt.subplots(figsize=(10, 15))
    for count,column_name in enumerate (colunms,start=1):
        plt.subplot(matriz[0], matriz[1], count)
        sns.histplot(data[column_name], color=listaCor[count-1],kde=True)
        plt.title(dicionario[column_name],fontsize=14, fontweight='bold',fontfamily='serif')   
        plt.xlabel("")
        plt.ylabel("")
    plt.show()

def boxPlot(data,colunms,listaCor,matriz=[]):
    plt.subplots(figsize=(10, 15))
    for count,column_name in enumerate (colunms,start=1):
        plt.subplot(matriz[0], matriz[1], count)
        sns.boxplot(data=data[column_name], color=listaCor[count-1])
        plt.title(dicionario[column_name],fontsize=14, fontweight='bold',fontfamily='serif')   
        plt.xlabel("")
        plt.ylabel("")
    plt.show()

def outrasvisoes():
    fig, axs = plt.subplots(8,2,figsize=(16,16))
    sns.set_style("darkgrid", {"grid.color": "0.6", "grid.linestyle": "-"})
    # Sex vs MI C_risco
    axs[0,0].text(0.5,0.5,'Risco por Sexo\n__________',
                  horizontalalignment='center',
                  verticalalignment='center',
                  fontweight='bold',fontfamily='serif')
    axs[0,0].set_xticks([])
    axs[0,0].set_yticks([])
    axs[0,0].grid(False)
    sns.countplot(ax=axs[0,1], x='C_sexo', hue='C_risco', data=df_origin).legend(title =dicionario[colunas_categoricas[-1]] )
    # I renamed the xticks from '0' and '1' to 'Female' and 'Male', respectively.
    axs[0,1].set(ylabel='')
    axs[0,1].set(xticks=([0,1]))
    axs[0,1].set(xticklabels=(['Mulher','Homem']))

    axs[1,0].text(0.5,0.5,'Risco por\n Número de Vasos\n__________',
                  horizontalalignment='center',
                  verticalalignment='center',
                  fontweight='bold',fontfamily='serif')
    axs[1,0].set_xticks([])
    axs[1,0].set_yticks([])
    axs[1,0].grid(False)
    sns.kdeplot(ax=axs[1,1], x='C_n_vasos', hue='C_risco', data=df_origin,
                    fill=True, alpha=0.6);
    axs[1,1].set(ylabel='')

    axs[2,0].text(0.5,0.5,'Risco por\n Frequência Cardiaca\n__________',
                  horizontalalignment='center',
                  verticalalignment='center',
                  fontweight='bold',fontfamily='serif')
    axs[2,0].set_xticks([])
    axs[2,0].set_yticks([])
    axs[2,0].grid(False)
    #sns.boxenplot(ax=axs[2,1], x='C_risco', y='Q_freq_card', data=df_origin);
    sns.kdeplot(ax=axs[2,1], x='Q_freq_card', hue='C_risco', data=df_origin,
                    fill=True, alpha=0.6);
    axs[2,1].set(ylabel='')
    axs[3,0].text(0.5,0.5,'Risco por Idade\n__________',
                 horizontalalignment='center',
                 verticalalignment='center',
                 fontweight='bold',fontfamily='serif')
    axs[3,0].set_xticks([])
    axs[3,0].set_yticks([])
    axs[3,0].grid(False)
    sns.kdeplot(ax=axs[3,1], x='Q_idade', hue='C_risco', data=df_origin,
                    fill=True, alpha=0.6);
    axs[3,1].set(ylabel='')

    axs[4,0].text(0.5,0.5,'Risco por\n Tipo de Dor no Peito\n__________',
                  horizontalalignment='center',
                  verticalalignment='center',
                  fontweight='bold',fontfamily='serif')
    axs[4,0].text(1,0.5,'0 - Typical angina\n1 - Atypical angina\n2 - Non-anginal pain\n3 - Asymptomatic',
                  horizontalalignment='right',
                  verticalalignment='center',)
    axs[4,0].set_xticks([])
    axs[4,0].set_yticks([])
    axs[4,0].grid(False)
    sns.kdeplot(ax=axs[4,1], x='C_d_peito', hue='C_risco', data=df_origin,
                    fill=True, alpha=0.6);
    axs[4,1].set(ylabel='')

    axs[5,0].text(0.5,0.5,'Risco por\n Glicemia em Jejum\n__________',
                  horizontalalignment='center',
                  verticalalignment='center',
                  fontweight='bold',fontfamily='serif')
    axs[5,0].set_xticks([])
    axs[5,0].set_yticks([])
    axs[5,0].grid(False)
    sns.countplot(ax=axs[5,1], x='C_glic', hue='C_risco', data=df_origin).legend(title =dicionario[colunas_categoricas[-1]])
    axs[5,1].set(xticks=([0,1]))
    axs[5,1].set(xticklabels=(['<120','>120']));
    axs[5,1].set(ylabel='')

    axs[6,0].text(0.5,0.5,'Risco por Colesterol\n \n__________',
                  horizontalalignment='center',
                  verticalalignment='center',
                  fontweight='bold',fontfamily='serif')
    axs[6,0].set_xticks([])
    axs[6,0].set_yticks([])
    axs[6,0].grid(False)
    sns.kdeplot(ax=axs[6,1], x='Q_colest', hue='C_risco', data=df_origin, fill=True, alpha=0.5);
    axs[6,1].set(ylabel='')

    axs[7,0].text(0.5,0.5,'Risco por\n Eletrocardiograma\n__________',
                  horizontalalignment='center',
                  verticalalignment='center',
                  fontweight='bold',fontfamily='serif')
    #axs[7,0].text(1,0.5,'0 - Normal ECG\n1 - ST-T Abn\n2 - LVH',
    #              horizontalalignment='right',
    #              verticalalignment='center',)
    axs[7,0].set_xticks([])
    axs[7,0].set_yticks([])
    axs[7,0].grid(False)
    sns.countplot(ax=axs[7,1], x='C_eletro', hue='C_risco', data=df_origin).legend(title =dicionario[colunas_categoricas[-1]])
    axs[7,1].set(ylabel='')
    axs[7,1].set(xlabel='')
    axs[7,1].set(xticks=([0,1,2]))
    axs[7,1].set(xticklabels=(['Normal','ST-T Abn','LVH']));

# %% [markdown]
# ###  Outliers

# %%
#Recebe daFrame e as Features com dados Quantitativos
def removeOutlier(data,colunms):
    pandasDF = data.copy()
    list_aux = np.array
    print('Beginning Shape',pandasDF.shape)
    for column_name in colunms:

        Q1 = np.percentile(pandasDF[column_name], 25,
                           interpolation = 'midpoint')

        Q3 = np.percentile(pandasDF[column_name], 75,
                           interpolation = 'midpoint')
        #Intervalo interquartil
        IQR = Q3 - Q1

        # Upper bound
        upper = pandasDF.index[(pandasDF[column_name]>=(Q3+(1.5*IQR)))].tolist() 
        # Lower bound
        lower = pandasDF.index[(pandasDF[column_name]<=(Q1-(1.5*IQR)))].tolist() 

        print(50*'*')
        print(dicionario[column_name])
        print('Limite Superior->',upper)
        print('Limite Inferior->',lower)

        pandasDF.drop(upper, inplace = True)
        pandasDF.drop(lower, inplace = True)
    print('End Shape',pandasDF.shape)
    return pandasDF

# %% [markdown]
# ### Frequência das Classes Categóricas

# %%
#Exibe frequência relativas das Classes  
#recebe features categoricas e dataFrame  
def freq_classes(columns_categoricas,data):
    for column in columns_categoricas:
        print('********',dicionario[column],'**********')
        print('Categoria    Freq')
        for i in data[column].value_counts().sort_index().index:
            print('   {0}       {1}%'.format(i,round((data[column].value_counts().sort_index()/len(data))[i]*100,2)))
        print(30*'-')

# %% [markdown]
# ### Ajuste de Dados

# %%
def normMinMax(data):
    #from sklearn.preprocessing import MinMaxScaler
    pandasDF = data.copy()
    x = pandasDF.iloc[:,:-1].values #returns a numpy array
    min_max_scaler = MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)
    pandasDF.iloc[:,:-1] = x_scaled
    return pandasDF

#Standarlization
def standard(data):
    #from sklearn.preprocessing import StandardScaler  
    pandasDF = datata.copy()
    x = pandasDF.iloc[:,:-1].values
    scaler = StandardScaler() 
    x_scaled = scaler.fit_transform(x)
    pandasDF.iloc[:,:-1] = x_scaled
    return pandasDF

# %% [markdown]
# ### Automatic Feature Selection in Python

# %%
#Retorna Lista e DF das Feactures Selecionadas 
def featuresSelection(data,target,corr_limit):
    #from featurewiz import featurewiz
    #np.random.seed(1234)
    features, train = featurewiz(data, target, corr_limit, verbose=2, sep=",",
    header=0,test_data="", feature_engg="", category_encoders="")
    return features, train

#Compara e Imprime as Feaactures entre os DF
def comparaFeatures(df1,df2,dfName):
    lista = [element for element in df1.columns if element not in df2.columns]
    if(lista == []):
        print(50*'*')
        print('Conjunto {0} -> Não Houve Eliminação de feature'.format(dfName))
        print(50*'*')
    else:
        print(50*'*')
        print('Conjunto {0} :'.format(dfName))
        for facture in lista:
            print('Feature Eliminada ->',dicionario[facture])
            print(50*'*')

# %% [markdown]
# ### Funções para Treinamento e Avaliação de Modelos de ML

# %% [markdown]
# #### Hyperparameter Tuning

# %%
dic_Hyperparameter={
    'knn':{
        "n_neighbors":[3,5,10,20,30],
        "weights":['uniform','distance'],
        "algorithm":['kd_tree','ball_tree','brute'],
        "leaf_size":[3,5,10,20,30],
        "p":[1,2],
        "metric":['euclidean','manhattan','chebyshev']
        },
    'svm':{
        "degree":[2,3,4,5],
        "C": [0.1, 1, 10, 100, 1000], 
        "gamma": [1, 0.1, 0.01, 0.001, 0.0001],
        "kernel": ['rbf','poly','linear']
        },
    'dTree':{
        "criterion":['gini', 'entropy','log_loss'],
        "splitter":['best','random'],
        "max_depth":[2,4,6,8,10],
        "min_samples_split":[2,3,4,5],
        'min_samples_leaf':[3,5,7,9],
        "max_features":['auto','sqrt','log2'] 
    },
    'rForest':{
            'bootstrap':[True],
            'max_depth':[2,4,6,8,10],
            'max_features':['auto','sqtr'],
            'min_samples_leaf':[3,5,7,8,9],
            'min_samples_split':[2,3,4,5],
            'n_estimators':[30,40,50,75]
    }
}

# %% [markdown]
# #### GridSerachCV

# %%
#from sklearn.model_selection import GridSearchCV
'''def gridsearch_cv(alg, params, df, target_col, folds=5):
    clf = GridSearchCV(alg, params, cv=folds)
    clf.fit(df[df.columns.difference([target_col])], df[target_col])

    print("--------------------------------")
    best_model = clf.best_estimator_

    print("Best Params: ")
    print(clf.best_params_)
    print("--------------------------------")

    print("mean_fit_time:",clf.cv_results_['mean_fit_time'].mean())  
    print("mean_score_time:",clf.cv_results_['mean_score_time'].mean())
    print("mean_test_score:",clf.cv_results_['mean_test_score'].mean())
    return best_model
'''
def gridSearch(alg,params):
    return GridSearchCV(alg,params,cv=5,
                             scoring="accuracy",
                             verbose=True,
                             return_train_score = True,
                             n_jobs=-1)

#******************************************************************#

# %% [markdown]
# #### Random Search

# %%
#RandomSearch

#from sklearn.model_selection import RandomizedSearchCV
#def randomSearch(alg,params,n_inter):
#    return RandomizeSearchCV(alg.params,n_inter,
#                            scoring="accuracy",verbose=True,cv=5,
#                            n_jobs=-1,random_state=42)

# %% [markdown]
# #### Treino X Teste

# %%
def treinoTeste(df,target):
#from sklearn.model_selection import train_test_split
    target_col = target
    train_set = 0.66
    return train_test_split(
        df[df.columns.difference([target_col])], 
        df[target_col], 
        test_size=1-train_set, 
        random_state=42
    )

# %% [markdown]
# #### Métricas

# %%
#from sklearn.metrics import confusion_matrix
#from sklearn.metrics import plot_confusion_matrix
#import matplotlib.pyplot as plt

def metricas(model,X_test,y_test,matrizModel=1):
    predicted_values = model.predict(X_test)
    true_values = y_test
    
    if(matrizModel!=1):
        #cm = confusion_matrix(true_values, predicted_values)
        print("       Confusion Matrix")
        #print(cm)
        plot_confusion_matrix(model, X_test, y_test)
        plt.grid(b=False)
        plt.show()
    else:    
        #ncm = confusion_matrix(true_values, predicted_values, normalize='true')
        print("      Normalized Confusion Matrix")
        #print(ncm)
        plot_confusion_matrix(model, X_test, y_test, normalize='true') 
        plt.grid(b=False)
        plt.show()
    
    print(50*"-")
    print()
    #from sklearn.metrics import f1_score, recall_score, precision_score
    print( "Macro F1: ", f1_score(true_values, predicted_values, average='macro') )
    print( "Micro F1: ",f1_score(true_values, predicted_values, average='micro') )
    print( "Weighted F1: ",f1_score(true_values, predicted_values, average='weighted') )
    print( "F1:",f1_score(true_values, predicted_values, average=None) )
    print(50*"-")
    print( "Macro Recall: ", recall_score(true_values, predicted_values, average='macro') )
    print( "Micro Recall: ", recall_score(true_values, predicted_values, average='micro') )
    print( "Weighted Recall: ", recall_score(true_values, predicted_values, average='weighted') )
    print( "Recall:", recall_score(true_values, predicted_values, average=None) )
    print(50*"-")
    print( "Macro Precision: ", precision_score(true_values, predicted_values, average='macro') )
    print( "Micro Precision: ", precision_score(true_values, predicted_values, average='micro') )
    print( "Weighted Precision: ", precision_score(true_values, predicted_values, average='weighted') )
    print( "Precision:", precision_score(true_values, predicted_values, average=None) )
    print(50*"-")
    
    #False Positive Rate
    tn, fp, fn, tp = confusion_matrix(y_test, predicted_values).ravel()
    precision = tp/(tp + fp)
    recall = tp/(tp + fn)
    fpr = fp/(fp + tn)
    print('False Positive Rate: ',fpr)
    print(50*"-")
    print()
    #from sklearn.metrics import classification_report
    print( classification_report(true_values, predicted_values))

# %% [markdown]
# ### Funções de Interpretabilidade

# %%
def interpret(model,X_teste):
    explainer = shap.Explainer(model.predict, X_test)
    return explainer(X_test)

def shap_plots(shap_values):
    shap.plots.bar(shap_values)
    shap.summary_plot(shap_values, plot_type='violin')

# %% [markdown]
# # Análise Exploratória

# %% [markdown]
# ## Importando DataFrame

# %%
df_origin = pd.read_csv('heart.csv')

# %% [markdown]
# ## Alterando Nome das Colunas e Separando por tipo

# %%
# Observando os nomes originais
print(list(df_origin.columns))
# Out:
# ['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh', 'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output']

# %%
#Crianndo um dicionário de Dados
#Deixando a  compreensão das features mais intuitivas
#Os Valores do dicionário também serão utilizados para nomear os Títulos dos nossos Gráficos 
#de forma Automática 

#Importante: o Prefixo determina se o tipo da Variável(C_ = Categórica e Q_ = Quantitativa) 
dicionario = {
    'Q_idade':'Idade',
    'C_sexo':'Sexo',
    'C_d_peito':'Tipo de Dor no Peito',
    'Q_p_arterial' :'Pressão Arterial em Repouso',
    'Q_colest':'Colesterol',
    'C_glic':'Glicemia em Jejum',
    'C_eletro':'Eletrocardiograma',
    'Q_freq_card':'Frequência Cardíaca',
    'C_angina':'Angina induzida',
    'Q_pico' :'Pico Anterior',
    'C_inclinacao' :'Inclinação',
    'C_n_vasos':'Número de Vasos',
    'C_t_estresse': 'Teste de Estresse',
    'C_risco':'Risco'
}
#Alterando Nomes das Colunas
df_origin.columns = dicionario.keys()

# %%
#Criando Listas para armazenar os nomes das features conforme o tipo
colunas_categoricas = []
colunas_quantitativas = []


[colunas_categoricas.append(nameColumn) if nameColumn[0] == 'C' 
 else colunas_quantitativas.append(nameColumn) for nameColumn in df_origin.columns]

print("Colunas Categóricas:")
print(colunas_categoricas)
print(100*'*')
print(100*'*')
print("Colunas Quantitativas:")
print(colunas_quantitativas)
# Out:
# Colunas Categóricas:
# ['C_sexo', 'C_d_peito', 'C_glic', 'C_eletro', 'C_angina', 'C_inclinacao', 'C_n_vasos', 'C_t_estresse', 'C_risco']
# ****************************************************************************************************
# ****************************************************************************************************
# Colunas Quantitativas:
# ['Q_idade', 'Q_p_arterial', 'Q_colest', 'Q_freq_card', 'Q_pico']

# %% [markdown]
# ## Informações do DataFrame

# %%
df_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Q_idade       303 non-null    int64
#  1   C_sexo        303 non-null    int64
#  2   C_d_peito     303 non-null    int64
#  3   Q_p_arterial  303 non-null    int64
#  4   Q_colest      303 non-null    int64
#  5   C_glic        303 non-null    int64
#  6   C_eletro      303 non-null    int64
#  7   Q_freq_card   303 non-null    int64
#  8   C_angina      303 non-null    int64
#  9   Q_pico        303 non-null    float64
#  10  C_inclinacao  303 non-null    int64
#  11  C_n_vasos     303 non-null    int64
#  12  C_t_estresse  303 non-null    int64
#  13  C_risco       303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df_origin.sample(5)
# Out:
#      Q_idade  C_sexo  C_d_peito  Q_p_arterial  Q_colest  C_glic  C_eletro  \
# 263       63       0          0           108       269       0         1
# 77        59       1          1           140       221       0         1
# 163       38       1          2           138       175       0         1
# 206       59       1          0           110       239       0         0
# 167       62       0          0           140       268       0         0
#
#      Q_freq_card  C_angina  Q_pico  C_inclinacao  C_n_vasos  C_t_estresse  \
# 263          169         1     1.8             1          2             2
# 77           164         1     0.0             2          0             2
# 163          173         0     0.0             2          4             2
# 206          142         1     1.2             1          1             3
# 167          160         0     3.6             0          2             2
#
#      C_risco
# 263        0
# 77         1
# 163        1
# 206        0
# ...

# %%
df_origin[colunas_quantitativas].describe()
# Out:
#           Q_idade  Q_p_arterial    Q_colest  Q_freq_card      Q_pico
# count  303.000000    303.000000  303.000000   303.000000  303.000000
# mean    54.366337    131.623762  246.264026   149.646865    1.039604
# std      9.082101     17.538143   51.830751    22.905161    1.161075
# min     29.000000     94.000000  126.000000    71.000000    0.000000
# 25%     47.500000    120.000000  211.000000   133.500000    0.000000
# 50%     55.000000    130.000000  240.000000   153.000000    0.800000
# 75%     61.000000    140.000000  274.500000   166.000000    1.600000
# max     77.000000    200.000000  564.000000   202.000000    6.200000

# %%
df_origin.isnull().sum()
# Out:
# Q_idade         0
# C_sexo          0
# C_d_peito       0
# Q_p_arterial    0
# Q_colest        0
# C_glic          0
# C_eletro        0
# Q_freq_card     0
# C_angina        0
# Q_pico          0
# C_inclinacao    0
# C_n_vasos       0
# C_t_estresse    0
# C_risco         0
# dtype: int64

# %% [markdown]
# ## Distribuição Colunas Categóricas

# %%
freq_classes(colunas_categoricas,df_origin)
# Out:
# ******** Sexo **********
# Categoria    Freq
#    0       31.68%
#    1       68.32%
# ------------------------------
# ******** Tipo de Dor no Peito **********
# Categoria    Freq
#    0       47.19%
#    1       16.5%
#    2       28.71%
#    3       7.59%
# ------------------------------
# ******** Glicemia em Jejum **********
# Categoria    Freq
#    0       85.15%
#    1       14.85%
# ------------------------------
# ******** Eletrocardiograma **********
# Categoria    Freq
#    0       48.51%
#    1       50.17%
#    2       1.32%
# ------------------------------
# ******** Angina induzida **********
# Categoria    Freq
#    0       67.33%
#    1       32.67%
# ------------------------------
# ******** Inclinação **********
# Categoria    Freq
#    0       6.93%
#    1       46.2%
#    2       46.86%
# ------------------------------
# ******** Número de Vasos **********
# Categoria    Freq
#    0       57.76%
#    1       21.45%
#    2       12.54%
#    3       6.6%
# ...

# %%
#Plot
countPlot(df_origin,colunas_categoricas,matriz=[3,3])

# %% [markdown]
# ## Distribuição Colunas Quantitativas

# %%
cor = ["magenta", "green", "lightblue", "purple", "orange"]
histplot(df_origin,colunas_quantitativas,listaCor=cor,matriz=[3,2])

# %% [markdown]
# ### Outliers

# %%
cor = ["magenta", "green", "lightblue", "purple", "orange"]
boxPlot(df_origin,colunas_quantitativas,listaCor=cor,matriz=[3,2])

# %% [markdown]
# ## Outras Relações

# %%
outrasvisoes()

# %% [markdown]
# # Tratamento de Dados

# %% [markdown]
# ## Eliminando outliers

# %%
df_outliers_clean = removeOutlier(df_origin,colunas_quantitativas)
# Out:
# Beginning Shape (303, 14)
# **************************************************
# Idade
# Limite Superior-> []
# Limite Inferior-> []
# **************************************************
# Pressão Arterial em Repouso
# Limite Superior-> [8, 101, 110, 152, 195, 203, 223, 228, 241, 248, 260, 266, 292]
# Limite Inferior-> []
# **************************************************
# Colesterol
# Limite Superior-> [28, 85, 96, 220, 246]
# Limite Inferior-> []
# **************************************************
# Frequência Cardíaca
# Limite Superior-> []
# Limite Inferior-> [272]
# **************************************************
# Pico Anterior
# Limite Superior-> [204, 221, 250, 291, 295]
# Limite Inferior-> []
# End Shape (279, 14)

# %%
#plot
cor = ["magenta", "green", "pink", "purple", "orange"]
boxPlot(df_outliers_clean,colunas_quantitativas,listaCor=cor,matriz=[3,2])

# %%
#rodando mais uma vez para eliminar um outlier da coluna Colesterol 
df_outliers_clean = removeOutlier(df_outliers_clean,colunas_quantitativas)
# Out:
# Beginning Shape (279, 14)
# **************************************************
# Idade
# Limite Superior-> []
# Limite Inferior-> []
# **************************************************
# Pressão Arterial em Repouso
# Limite Superior-> []
# Limite Inferior-> []
# **************************************************
# Colesterol
# Limite Superior-> [39]
# Limite Inferior-> []
# **************************************************
# Frequência Cardíaca
# Limite Superior-> []
# Limite Inferior-> []
# **************************************************
# Pico Anterior
# Limite Superior-> []
# Limite Inferior-> []
# End Shape (278, 14)

# %%
print('Total de Registros Excluidos: ',df_origin.shape[0] - df_outliers_clean.shape[0])
# Out:
# Total de Registros Excluidos:  25

# %% [markdown]
# ## Eliminando Classes
#
# No Tópico Distribuição  Colunas Categóricas(3.4), observamos que não só existem um desbalanceamento das classes , como também, classes que apresentam frequências tão baixa, que dificilmente agregariam valor ao nosso aprendizado de máquina.
#
# Vamos observar como ficou a destribuição das features categóricas, avaliando as frequências das classes e eliminando-as, caso necessário.<br>
#
# - Classes cuja frequência seja menor de 10% serão eliminadas.
#
# A cada remoção de classe, será impresso a nova frequência relativa das classes. Orientando a decisão seguinte.
#
# *obs: Para referenciarmos os nomes das features utilizaremos os índices da variável 'colunas_categoricas'.
#
# 0 --> Sexo
#
# 1 --> Tipo de Dor no Peito
#
# 2 --> Glicemia em Jejum
#
# 3 --> Eletrocardiograma
#
# 4 --> Angina induzida
#
# 5 --> Inclinação
#
# 6 --> Número de Vasos
#
# 7 --> Teste de Estresse
#
# 8 --> Risco

# %%
#função retorna frequencia das classes 
freq_classes(colunas_categoricas,df_outliers_clean)
# Out:
# ******** Sexo **********
# Categoria    Freq
#    0       29.86%
#    1       70.14%
# ------------------------------
# ******** Tipo de Dor no Peito **********
# Categoria    Freq
#    0       45.68%
#    1       17.63%
#    2       29.5%
#    3       7.19%
# ------------------------------
# ******** Glicemia em Jejum **********
# Categoria    Freq
#    0       85.97%
#    1       14.03%
# ------------------------------
# ******** Eletrocardiograma **********
# Categoria    Freq
#    0       47.12%
#    1       52.16%
#    2       0.72%
# ------------------------------
# ******** Angina induzida **********
# Categoria    Freq
#    0       68.71%
#    1       31.29%
# ------------------------------
# ******** Inclinação **********
# Categoria    Freq
#    0       5.4%
#    1       45.68%
#    2       48.92%
# ------------------------------
# ******** Número de Vasos **********
# Categoria    Freq
#    0       57.91%
#    1       22.66%
#    2       11.87%
#    3       5.76%
# ...

# %%
#Novo Data para tratarmos as novas limpezas
df_class_clean = df_outliers_clean.copy()

# %% [markdown]
# ### Teste de Estresse
# Lista índice: 7 <br>
# Classe: 0 <br>
# Frequência: 0.72%

# %%
lista_aux = df_class_clean.index[(df_class_clean[colunas_categoricas[7]]==0)].tolist()

#drop
df_class_clean.drop(lista_aux,inplace = True)

# %%
#função retorna frequencia das classes 
freq_classes(colunas_categoricas,df_class_clean)
# Out:
# ******** Sexo **********
# Categoria    Freq
#    0       29.71%
#    1       70.29%
# ------------------------------
# ******** Tipo de Dor no Peito **********
# Categoria    Freq
#    0       45.65%
#    1       17.75%
#    2       29.35%
#    3       7.25%
# ------------------------------
# ******** Glicemia em Jejum **********
# Categoria    Freq
#    0       86.23%
#    1       13.77%
# ------------------------------
# ******** Eletrocardiograma **********
# Categoria    Freq
#    0       47.1%
#    1       52.17%
#    2       0.72%
# ------------------------------
# ******** Angina induzida **********
# Categoria    Freq
#    0       68.84%
#    1       31.16%
# ------------------------------
# ******** Inclinação **********
# Categoria    Freq
#    0       5.43%
#    1       45.65%
#    2       48.91%
# ------------------------------
# ******** Número de Vasos **********
# Categoria    Freq
#    0       57.61%
#    1       22.83%
#    2       11.96%
#    3       5.8%
# ...

# %% [markdown]
# ### Eletrocardiograma
# Lista índice: 3 <br>
# Classe: 2 <br>
# Frequência: 0.72%

# %%
lista_aux = df_class_clean.index[(df_class_clean[colunas_categoricas[3]]==2)].tolist()

#drop
df_class_clean.drop(lista_aux,inplace = True)

# %%
#função retorna frequencia das classes 
freq_classes(colunas_categoricas,df_class_clean)
# Out:
# ******** Sexo **********
# Categoria    Freq
#    0       29.2%
#    1       70.8%
# ------------------------------
# ******** Tipo de Dor no Peito **********
# Categoria    Freq
#    0       45.62%
#    1       17.88%
#    2       29.2%
#    3       7.3%
# ------------------------------
# ******** Glicemia em Jejum **********
# Categoria    Freq
#    0       86.13%
#    1       13.87%
# ------------------------------
# ******** Eletrocardiograma **********
# Categoria    Freq
#    0       47.45%
#    1       52.55%
# ------------------------------
# ******** Angina induzida **********
# Categoria    Freq
#    0       68.98%
#    1       31.02%
# ------------------------------
# ******** Inclinação **********
# Categoria    Freq
#    0       5.47%
#    1       45.26%
#    2       49.27%
# ------------------------------
# ******** Número de Vasos **********
# Categoria    Freq
#    0       57.66%
#    1       22.63%
#    2       12.04%
#    3       5.84%
#    4       1.82%
# ...

# %% [markdown]
# ### Número de Vasos
# Lista índice: 6 <br>
# Classe: 3 , 4 <br>
# Frequência: 5,84% e 1.82% Respectivamente

# %%
lista_aux = df_class_clean.index[(df_class_clean[colunas_categoricas[6]]==4)].tolist()

#drop
df_class_clean.drop(lista_aux,inplace = True)

# %%
lista_aux = df_class_clean.index[(df_class_clean[colunas_categoricas[6]]==3)].tolist()

#drop
df_class_clean.drop(lista_aux,inplace = True)

# %%
freq_classes(colunas_categoricas,df_class_clean)
# Out:
# ******** Sexo **********
# Categoria    Freq
#    0       30.83%
#    1       69.17%
# ------------------------------
# ******** Tipo de Dor no Peito **********
# Categoria    Freq
#    0       45.06%
#    1       18.58%
#    2       28.46%
#    3       7.91%
# ------------------------------
# ******** Glicemia em Jejum **********
# Categoria    Freq
#    0       87.35%
#    1       12.65%
# ------------------------------
# ******** Eletrocardiograma **********
# Categoria    Freq
#    0       46.64%
#    1       53.36%
# ------------------------------
# ******** Angina induzida **********
# Categoria    Freq
#    0       69.17%
#    1       30.83%
# ------------------------------
# ******** Inclinação **********
# Categoria    Freq
#    0       5.93%
#    1       43.87%
#    2       50.2%
# ------------------------------
# ******** Número de Vasos **********
# Categoria    Freq
#    0       62.45%
#    1       24.51%
#    2       13.04%
# ------------------------------
# ...

# %% [markdown]
# ### Tipo de Dor no Peito
# Lista índice: 1 <br>
# Classe: 3 <br>
# Frequência: 7.91%

# %%
lista_aux = df_class_clean.index[(df_class_clean[colunas_categoricas[1]]==3)].tolist()

#drop
df_class_clean.drop(lista_aux,inplace = True)

# %%
freq_classes(colunas_categoricas,df_class_clean)
# Out:
# ******** Sexo **********
# Categoria    Freq
#    0       31.76%
#    1       68.24%
# ------------------------------
# ******** Tipo de Dor no Peito **********
# Categoria    Freq
#    0       48.93%
#    1       20.17%
#    2       30.9%
# ------------------------------
# ******** Glicemia em Jejum **********
# Categoria    Freq
#    0       88.41%
#    1       11.59%
# ------------------------------
# ******** Eletrocardiograma **********
# Categoria    Freq
#    0       45.92%
#    1       54.08%
# ------------------------------
# ******** Angina induzida **********
# Categoria    Freq
#    0       68.24%
#    1       31.76%
# ------------------------------
# ******** Inclinação **********
# Categoria    Freq
#    0       5.58%
#    1       43.78%
#    2       50.64%
# ------------------------------
# ******** Número de Vasos **********
# Categoria    Freq
#    0       62.23%
#    1       25.32%
#    2       12.45%
# ------------------------------
# ...

# %% [markdown]
# ### Teste de Estresse
# Lista índice: 7 <br>
# Classe: 1 <br>
# Frequência: 5.58%

# %%
lista_aux = df_class_clean.index[(df_class_clean[colunas_categoricas[7]]==1)].tolist()

#drop
df_class_clean.drop(lista_aux,inplace = True)

# %%
freq_classes(colunas_categoricas,df_class_clean)
# Out:
# ******** Sexo **********
# Categoria    Freq
#    0       33.64%
#    1       66.36%
# ------------------------------
# ******** Tipo de Dor no Peito **********
# Categoria    Freq
#    0       47.27%
#    1       20.91%
#    2       31.82%
# ------------------------------
# ******** Glicemia em Jejum **********
# Categoria    Freq
#    0       89.09%
#    1       10.91%
# ------------------------------
# ******** Eletrocardiograma **********
# Categoria    Freq
#    0       45.45%
#    1       54.55%
# ------------------------------
# ******** Angina induzida **********
# Categoria    Freq
#    0       69.09%
#    1       30.91%
# ------------------------------
# ******** Inclinação **********
# Categoria    Freq
#    0       5.45%
#    1       41.82%
#    2       52.73%
# ------------------------------
# ******** Número de Vasos **********
# Categoria    Freq
#    0       63.18%
#    1       25.0%
#    2       11.82%
# ------------------------------
# ...

# %% [markdown]
# ### Inclinação
# Lista índice: 5 <br>
# Classe: 0 <br>
# Frequência: 5.45%

# %%
lista_aux = df_class_clean.index[(df_class_clean[colunas_categoricas[5]]==0)].tolist()

#drop
df_class_clean.drop(lista_aux,inplace = True)

# %%
freq_classes(colunas_categoricas,df_class_clean)
# Out:
# ******** Sexo **********
# Categoria    Freq
#    0       34.62%
#    1       65.38%
# ------------------------------
# ******** Tipo de Dor no Peito **********
# Categoria    Freq
#    0       47.6%
#    1       21.15%
#    2       31.25%
# ------------------------------
# ******** Glicemia em Jejum **********
# Categoria    Freq
#    0       90.38%
#    1       9.62%
# ------------------------------
# ******** Eletrocardiograma **********
# Categoria    Freq
#    0       44.71%
#    1       55.29%
# ------------------------------
# ******** Angina induzida **********
# Categoria    Freq
#    0       69.71%
#    1       30.29%
# ------------------------------
# ******** Inclinação **********
# Categoria    Freq
#    1       44.23%
#    2       55.77%
# ------------------------------
# ******** Número de Vasos **********
# Categoria    Freq
#    0       62.5%
#    1       25.48%
#    2       12.02%
# ------------------------------
# ******** Teste de Estresse **********
# ...

# %% [markdown]
# ### Plot

# %%
#Plot
countPlot(df_class_clean,colunas_categoricas,matriz=[3,3])

# %%
print('Total de Registros Excluídos: ',df_outliers_clean.shape[0] - df_class_clean.shape[0])
print(50*'*')
print('DataFrame Origin - DataFrame Class Clean: ',df_origin.shape[0] - df_class_clean.shape[0])
# Out:
# Total de Registros Excluídos:  70
# **************************************************
# DataFrame Origin - DataFrame Class Clean:  95

# %% [markdown]
# ## Balanceamento de Classes

# %% [markdown]
# ### Balanceamento da classe Glicemia em jejum

# %%
#from imblearn.over_sampling import SMOTE
smt = SMOTE(random_state = 1 )

# %%
#Index coluna Gicemia em jejum
i = 5
colunmn_name = df_class_clean.columns[i]
print(colunmn_name)
# Out:
# C_glic

# %%
x = df_class_clean.drop(colunmn_name,axis = 1)
y = df_class_clean[colunmn_name]

x,y = smt.fit_resample(x,y)

df_balance = x
df_balance.insert(i,colunmn_name,y,True)

# %%
#freq_classes(colunas_categoricas,df_balance)

# %%
#Plot
countPlot(df_balance,colunas_categoricas,matriz=[3,3])

# %% [markdown]
# ### Balanceamento da classe Número de Vasos

# %%
#Index coluna Número de Vasos
i = 11
colunmn_name = df_balance.columns[i]
print(colunmn_name)
# Out:
# C_n_vasos

# %%
x = df_balance.drop(colunmn_name,axis = 1)
y = df_balance[colunmn_name]

x,y = smt.fit_resample(x,y)

df_balance = x
df_balance.insert(i,colunmn_name,y,True)

# %%
#Plot
countPlot(df_balance,colunas_categoricas,matriz=[3,3])

# %% [markdown]
# ### Balanceamento da classe Risco

# %%
#Index coluna Número de Vasos
i = 13
colunmn_name = df_balance.columns[i]
print(colunmn_name)
# Out:
# C_risco

# %%
x = df_balance.drop(colunmn_name,axis = 1)
y = df_balance[colunmn_name]

x,y = smt.fit_resample(x,y)

df_balance = x
df_balance.insert(i,colunmn_name,y,True)

# %%
df_balance.shape
# Out:
# (950, 14)

# %%
#Plot
countPlot(df_balance,colunas_categoricas,matriz=[3,3])

# %% [markdown]
# ## Padronização Dos Dados

# %%
df_norm = normMinMax(df_balance)
df_norm.head()
# Out:
#     Q_idade  C_sexo  C_d_peito  Q_p_arterial  Q_colest  C_glic  C_eletro  \
# 0  0.266667     0.0        0.5      0.545455  0.342105     0.0       0.0
# 1  0.600000     1.0        0.5      0.393939  0.482456     0.0       1.0
# 2  0.622222     0.0        0.0      0.393939  1.000000     0.0       1.0
# 3  0.600000     0.0        0.5      0.696970  0.736842     0.0       0.0
# 4  0.333333     1.0        0.5      0.393939  0.600877     0.0       1.0
#
#    Q_freq_card  C_angina    Q_pico  C_inclinacao  C_n_vasos  C_t_estresse  \
# 0     0.736842       0.0  0.388889           1.0        0.0           0.0
# 1     0.789474       0.0  0.222222           1.0        0.0           0.0
# 2     0.657895       1.0  0.166667           1.0        0.0           0.0
# 3     0.570175       0.0  0.361111           0.0        0.0           0.0
# 4     0.745614       0.0  0.000000           1.0        0.0           1.0
#
#    C_risco
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ## Seleção de Features

# %%
#Seleção de recursos new_df
features,pandasDF = featuresSelection(data = df_norm,target = colunas_categoricas[-1],corr_limit = 0.70)
# Out:
# ############################################################################################
# ############       F A S T   F E A T U R E  E N G G    A N D    S E L E C T I O N ! ########
# # Be judicious with featurewiz. Don't use it to create too many un-interpretable features! #
# ############################################################################################
# Skipping feature engineering since no feature_engg input...
# Skipping category encoding since no category encoders specified in input...
# **INFO: featurewiz can now read feather formatted files. Loading train data...
#     Shape of your Data Set loaded: (950, 14)
#     Loaded train data. Shape = (950, 14)
# No test data filename given...
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# ...

# %%
comparaFeatures(df_origin,df_norm,dfName = 'df_norm')
# Out:
# **************************************************
# Conjunto df_norm -> Não Houve Eliminação de feature
# **************************************************

# %% [markdown]
# # Treinamentos

# %% [markdown]
# ## Treino x Teste

# %%
#treino x Teste
X_train, X_test, y_train, y_test = treinoTeste(df=df_norm,target=colunas_categoricas[-1])

# %% [markdown]
# ## Instâncias dos Modelos

# %%
dTree = DecisionTreeClassifier()
knn = KNeighborsClassifier()
svm = SVC()
rForest = RandomForestClassifier()

# %% [markdown]
# ## KNN

# %%
# %%time
knn_model = gridSearch(knn,dic_Hyperparameter['knn'])
knn_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 900 candidates, totalling 4500 fits
# Wall time: 2min 11s
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['kd_tree', 'ball_tree', 'brute'],
#                          'leaf_size': [3, 5, 10, 20, 30],
#                          'metric': ['euclidean', 'manhattan', 'chebyshev'],
#                          'n_neighbors': [3, 5, 10, 20, 30], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              return_train_score=True, scoring='accuracy', verbose=True)

# %%
knn_model.best_score_
# Out:
# 0.9282031746031747

# %%
metricas(knn_model,X_test,y_test,matrizModel=1)
# Out:
#       Normalized Confusion Matrix
# --------------------------------------------------
#
# Macro F1:  0.919281045751634
# Micro F1:  0.9195046439628483
# Weighted F1:  0.9194257269471257
# F1: [0.91503268 0.92352941]
# --------------------------------------------------
# Macro Recall:  0.9187778289574697
# Micro Recall:  0.9195046439628483
# Weighted Recall:  0.9195046439628483
# Recall: [0.8974359  0.94011976]
# --------------------------------------------------
# Macro Precision:  0.9204238921001927
# Micro Precision:  0.9195046439628483
# Weighted Precision:  0.9199842516866801
# Precision: [0.93333333 0.90751445]
# --------------------------------------------------
# False Positive Rate:  0.10256410256410256
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92       156
#            1       0.91      0.94      0.92       167
#
# ...

# %% [markdown]
# ### Interpretabilidade

# %%
shap_values = interpret(knn_model,X_test)
# Out:
# Permutation explainer: 324it [10:35,  1.98s/it]

# %%
shap_plots(shap_values)

# %% [markdown]
# ## SVM

# %%
# %%time
svm_model = gridSearch(svm,dic_Hyperparameter['svm'])
svm_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Wall time: 41.8 s
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100, 1000], 'degree': [2, 3, 4, 5],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf', 'poly', 'linear']},
#              return_train_score=True, scoring='accuracy', verbose=True)

# %%
svm_model.best_score_
# Out:
# 0.9394285714285715

# %%
metricas(svm_model,X_test,y_test,matrizModel=1)
# Out:
#       Normalized Confusion Matrix
# --------------------------------------------------
#
# Macro F1:  0.941120033771791
# Micro F1:  0.9411764705882353
# Weighted F1:  0.9411821142698797
# F1: [0.93929712 0.94294294]
# --------------------------------------------------
# Macro Recall:  0.9412137263933671
# Micro Recall:  0.9411764705882353
# Weighted Recall:  0.9411764705882353
# Recall: [0.94230769 0.94011976]
# --------------------------------------------------
# Macro Precision:  0.9410444325070985
# Micro Precision:  0.9411764705882353
# Weighted Precision:  0.9412058123840435
# Precision: [0.93630573 0.94578313]
# --------------------------------------------------
# False Positive Rate:  0.057692307692307696
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       156
#            1       0.95      0.94      0.94       167
#
# ...

# %% [markdown]
# ### Interpretabilidade

# %%
shap_values = interpret(svm_model,X_test)
# Out:
# Permutation explainer: 324it [01:24,  3.39it/s]

# %%
shap_plots(shap_values)

# %% [markdown]
# ## Decision Tree

# %%
# %%time
dTree_model = gridSearch(dTree,dic_Hyperparameter['dTree'])
dTree_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1440 candidates, totalling 7200 fits
# Wall time: 23.5 s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [3, 5, 7, 9],
#                          'min_samples_split': [2, 3, 4, 5],
#                          'splitter': ['best', 'random']},
#              return_train_score=True, scoring='accuracy', verbose=True)

# %%
dTree_model.best_score_
# Out:
# 0.9122666666666668

# %%
metricas(dTree_model,X_test,y_test,matrizModel=1)
# Out:
#       Normalized Confusion Matrix
# --------------------------------------------------
#
# Macro F1:  0.9131253362022593
# Micro F1:  0.913312693498452
# Weighted F1:  0.9132627315528006
# F1: [0.90909091 0.91715976]
# --------------------------------------------------
# Macro Recall:  0.9127898050053739
# Micro Recall:  0.913312693498452
# Weighted Recall:  0.913312693498452
# Recall: [0.8974359  0.92814371]
# --------------------------------------------------
# Macro Precision:  0.9137426900584795
# Micro Precision:  0.913312693498452
# Weighted Precision:  0.9134937446816215
# Precision: [0.92105263 0.90643275]
# --------------------------------------------------
# False Positive Rate:  0.10256410256410256
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       156
#            1       0.91      0.93      0.92       167
#
# ...

# %% [markdown]
# ### Interpretabilidade

# %%
shap_values = interpret(dTree_model,X_test)
# Out:
# Permutation explainer: 324it [00:14,  6.59it/s]

# %%
shap_plots(shap_values)

# %% [markdown]
# ## Random Forest

# %%
# %%time
rForest_model = gridSearch(rForest,dic_Hyperparameter['rForest'])
rForest_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 800 candidates, totalling 4000 fits
# Wall time: 2min 13s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['auto', 'sqtr'],
#                          'min_samples_leaf': [3, 5, 7, 8, 9],
#                          'min_samples_split': [2, 3, 4, 5],
#                          'n_estimators': [30, 40, 50, 75]},
#              return_train_score=True, scoring='accuracy', verbose=True)

# %%
rForest_model.best_score_
# Out:
# 0.9330666666666666

# %%
metricas(rForest_model,X_test,y_test,matrizModel=1)
# Out:
#       Normalized Confusion Matrix
# --------------------------------------------------
#
# Macro F1:  0.9566060187317673
# Micro F1:  0.9566563467492261
# Weighted F1:  0.9566563467492261
# F1: [0.95512821 0.95808383]
# --------------------------------------------------
# Macro Recall:  0.9566060187317673
# Micro Recall:  0.9566563467492261
# Weighted Recall:  0.9566563467492261
# Recall: [0.95512821 0.95808383]
# --------------------------------------------------
# Macro Precision:  0.9566060187317673
# Micro Precision:  0.9566563467492261
# Weighted Precision:  0.9566563467492261
# Precision: [0.95512821 0.95808383]
# --------------------------------------------------
# False Positive Rate:  0.04487179487179487
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       156
#            1       0.96      0.96      0.96       167
#
# ...

# %% [markdown]
# ### Interpretabilidade

# %%
shap_values = interpret(rForest_model,X_test)
# Out:
# Permutation explainer: 324it [01:29,  3.20it/s]

# %%
shap_plots(shap_values)
